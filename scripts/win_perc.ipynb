# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
file_paths = ['../csvs/prem_tidy.csv', '../csvs/national_league_tidy.csv']
dfs = [pd.read_csv(i) for i in file_paths]

premier_league, national_league = dfs

# %%
def win_perc(i):
    i['Win_Perc'] = ((i['W']/i['Pl'])*100).round(2)

def position(i):
    i['Position'] = i.index +1

# %%
win_perc(premier_league)
win_perc(national_league)
position(premier_league)
position(national_league)

# %%
premier_league['League_name'] = 'Premier League'
national_league['League_name'] = 'National League'

# %%
tot_table = pd.concat([premier_league, national_league])

# %%
tot_table.head()
# Out:
#                 Team  Pl   W  D  L   F   A  GD  Pts  Win_Perc  Position  \
# 0          Liverpool  20  13  6  1  43  18  25   45     65.00         1
# 1    Manchester City  20  13  4  3  48  23  25   43     65.00         2
# 2        Aston Villa  21  13  4  4  43  27  16   43     61.90         3
# 3            Arsenal  20  12  4  4  37  20  17   40     60.00         4
# 4  Tottenham Hotspur  21  12  4  5  44  31  13   40     57.14         5
#
#       League_name
# 0  Premier League
# 1  Premier League
# 2  Premier League
# 3  Premier League
# 4  Premier League

# %%
tot_table.loc[tot_table['League_name'] == 'National League', 'Position'] /= 24/20

# %%
display(tot_table)
# Out:
#                         Team  Pl   W   D   L   F   A  GD  Pts  Win_Perc  \
# 0                  Liverpool  20  13   6   1  43  18  25   45     65.00
# 1            Manchester City  20  13   4   3  48  23  25   43     65.00
# 2                Aston Villa  21  13   4   4  43  27  16   43     61.90
# 3                    Arsenal  20  12   4   4  37  20  17   40     60.00
# 4          Tottenham Hotspur  21  12   4   5  44  31  13   40     57.14
# 5            West Ham United  20  10   4   6  33  30   3   34     50.00
# 6          Manchester United  21  10   2   9  24  29  -5   32     47.62
# 7   Brighton and Hove Albion  20   8   7   5  38  33   5   31     40.00
# 8                    Chelsea  21   9   4   8  35  31   4   31     42.86
# 9           Newcastle United  21   9   2  10  41  32   9   29     42.86
# 10   Wolverhampton Wanderers  20   8   4   8  30  31  -1   28     40.00
# 11               Bournemouth  19   7   4   8  28  35  -7   25     36.84
# 12                    Fulham  21   7   3  11  28  36  -8   24     33.33
# 13            Crystal Palace  20   5   6   9  22  29  -7   21     25.00
# 14         Nottingham Forest  20   5   5  10  24  35 -11   20     25.00
# 15                 Brentford  19   5   4  10  26  31  -5   19     26.32
# 16                 Everton *  21   8   3  10  24  28  -4   17     38.10
# 17                Luton Town  20   4   4  12  24  38 -14   16     20.00
# 18                   Burnley  21   3   3  15  21  42 -21   12     14.29
# 19          Sheffield United  20   2   3  15  15  49 -34    9     10.00
# 0               Chesterfield  26  21   2   3  66  33  33   65     80.77
# 1                    Bromley  28  16   8   4  49  29  20   56     57.14
# 2                     Barnet  28  17   4   7  57  40  17   55     60.71
# 3             Solihull Moors  27  13   7   7  43  37   6   46     48.15
# 4                 Altrincham  26  11  10   5  48  36  12   43     42.31
# 5            Oldham Athletic  27  11   9   7  43  38   5   42     40.74
# 6                   Rochdale  28  11   8   9  46  39   7   41     39.29
# 7                  Gateshead  26  11   7   8  50  38  12   40     42.31
# 8                 FC Halifax  27  10  10   7  30  27   3   40     37.04
# 9             Aldershot Town  26  12   4  10  45  47  -2   40     46.15
# 10                 Eastleigh  27  10   7  10  46  50  -4   37     37.04
# 11           Southend United  27  13   5   9  44  28  16   34     48.15
# 12                Wealdstone  25   9   6  10  34  36  -2   33     36.00
# 13         Maidenhead United  27   7  11   9  28  35  -7   32     25.93
# 14              Boreham Wood  27   7  11   9  33  42  -9   32     25.93
# 15         Hartlepool United  28   9   4  15  44  55 -11   31     32.14
# 16      Dagenham & Redbridge  27   8   6  13  34  39  -5   30     29.63
# 17                 York City  27   6  12   9  36  44  -8   30     22.22
# 18         Dorking Wanderers  26   8   4  14  30  45 -15   28     30.77
# 19                    Woking  27   7   6  14  28  37  -9   27     25.93
# 20          Ebbsfleet United  28   7   6  15  37  54 -17   27     25.00
# 21                 AFC Fylde  27   6   7  14  39  50 -11   25     22.22
# 22               Oxford City  28   6   6  16  40  54 -14   24     21.43
# 23    Kidderminster Harriers  28   4   8  16  20  37 -17   20     14.29
#
#      Position      League_name
# 0    1.000000   Premier League
# 1    2.000000   Premier League
# 2    3.000000   Premier League
# 3    4.000000   Premier League
# 4    5.000000   Premier League
# 5    6.000000   Premier League
# 6    7.000000   Premier League
# 7    8.000000   Premier League
# 8    9.000000   Premier League
# 9   10.000000   Premier League
# 10  11.000000   Premier League
# 11  12.000000   Premier League
# 12  13.000000   Premier League
# 13  14.000000   Premier League
# 14  15.000000   Premier League
# 15  16.000000   Premier League
# 16  17.000000   Premier League
# 17  18.000000   Premier League
# 18  19.000000   Premier League
# 19  20.000000   Premier League
# 0    0.833333  National League
# 1    1.666667  National League
# 2    2.500000  National League
# 3    3.333333  National League
# 4    4.166667  National League
# 5    5.000000  National League
# 6    5.833333  National League
# 7    6.666667  National League
# 8    7.500000  National League
# 9    8.333333  National League
# 10   9.166667  National League
# 11  10.000000  National League
# 12  10.833333  National League
# 13  11.666667  National League
# 14  12.500000  National League
# 15  13.333333  National League
# 16  14.166667  National League
# 17  15.000000  National League
# 18  15.833333  National League
# 19  16.666667  National League
# 20  17.500000  National League
# 21  18.333333  National League
# 22  19.166667  National League
# 23  20.000000  National League

# %%
tot_table = tot_table[tot_table['Team'] != "Everton *"] #removing everton as anomoly due to points deduction

# %%
fig, ax = plt.subplots(figsize = (15,18))

ax = sns.lineplot(data = tot_table, x = 'Position', y = 'Win_Perc', hue = 'League_name', linewidth = 5)
ax.set_xlabel('\nLeague Position (standardised)', fontsize = 15)
ax.set_ylabel('Win Percentage\n', fontsize = 15)
ax.axvline(x=17, color='grey', linestyle='--')
ax.axvline(x=4, color='grey', linestyle='--')
ax.axvline(x=7, color='grey', linestyle='--')
plt.xticks(fontsize=11)
plt.yticks(fontsize = 11)
plt.savefig('Win_percentage.pdf')
plt.legend(fontsize = 15)
plt.show()
